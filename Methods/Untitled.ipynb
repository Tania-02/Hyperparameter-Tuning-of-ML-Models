# %%
import matplotlib.pyplot as plt

# %%
x = [10, 20, 30, -40, 50]
x_axis = [0, 1, 2, 3, 4]
y = [0.95, 0.91, 0.96, 0.99, 0.88]

plt.plot(x_axis, y, label='train curve')
plt.xticks(x_axis, x)
plt.title('Hyper-parameter VS accuracy plot')
plt.legend()
plt.show()
